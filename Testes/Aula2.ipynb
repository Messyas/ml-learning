# %%
conda list
# Out:
# # packages in environment at /home/takana/miniconda3/envs/tf:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# absl-py                   2.1.0                    pypi_0    pypi
# anyio                     4.6.0                    pypi_0    pypi
# argon2-cffi               23.1.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# arrow                     1.3.0                    pypi_0    pypi
# asttokens                 2.4.1                    pypi_0    pypi
# astunparse                1.6.3                    pypi_0    pypi
# async-lru                 2.0.4                    pypi_0    pypi
# attrs                     24.2.0                   pypi_0    pypi
# babel                     2.16.0                   pypi_0    pypi
# ...

# %%
v_n1 = int(input('Entre com o primeiro num: '))
v_n2 = int(input('\nEntre com o segundo num: '))
v_total = v_n1 + v_n2
print('\n', v_total)

if(v_total % 2) == 0:
    print('\nNúmero par.')
else:
    print('\nNúmero ímpar.')
# Out:
# Entre com o primeiro num:  20
#
# Entre com o segundo num:  5
#  25
#
# Número ímpar.

# %%
v_peso = float(input('Digite seu peso: '))
v_altura = float(input('\nDigite sua altura: '))
v_imc = v_peso / (v_altura ** 2) # ** é ao quadrado
print('\nSeu IMC é: ', v_imc)

if (v_imc < 18.5):
    print('\nAbaixo do Peso')
elif v_imc >= 18.5 and v_imc <= 24.9:
    print('\nPeso Normal')
elif v_imc >= 24.9 and v_imc <= 29.9:
    print('\nSobrepeso')
elif v_imc >= 30 and v_imc <= 34.9:
    print('\nObesidade grau I')
elif v_imc >= 35 and v_imc <= 39.9:
    print('\nObesidade grau II')
elif v_imc >= 40:
    print('\nObesidade grau III ou mórbida')
# Out:
# Digite seu peso:  76.80
#
# Digite sua altura:  1.76
# Seu IMC é:  24.793388429752067
#
# Peso Normal
